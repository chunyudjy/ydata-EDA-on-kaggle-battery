# %%
import numpy as np
import pandas as pd
from ydata_profiling import ProfileReport

df = pd.DataFrame(np.random.rand(100, 5), columns=["a", "b", "c", "d", "e"])

df
# Out:
#            a         b         c         d         e
# 0   0.326912  0.809046  0.417966  0.546189  0.170436
# 1   0.712121  0.505545  0.906849  0.327954  0.999039
# 2   0.366073  0.172141  0.456005  0.780412  0.057106
# 3   0.218279  0.547377  0.880772  0.837175  0.942961
# 4   0.254829  0.401165  0.743788  0.830636  0.794414
# ..       ...       ...       ...       ...       ...
# 95  0.269694  0.652662  0.513739  0.430709  0.773341
# 96  0.264002  0.902630  0.898436  0.367928  0.620282
# 97  0.119057  0.520700  0.819137  0.842878  0.391486
# 98  0.364571  0.695416  0.334297  0.348365  0.545124
# 99  0.985912  0.015202  0.836488  0.183303  0.714332
#
# [100 rows x 5 columns]

# %%
profile = ProfileReport(df, title="Profiling Report")
# There are two interfaces to consume the report inside a Jupyter notebook: through widgets and through an embedded HTML report.

# %%
#The above is achieved by simply displaying the report as a set of widgets. In a Jupyter Notebook, run:
# profile.to_widgets()
# 👀👀👀👀
# error:ValueError: ('widget type not understood', 'overview_tabs')
# 这个报错通常意味着 to_widgets() 生成的自定义小部件（如 overview_tabs）没被前端的 ipywidgets 正确识别/渲染。最常见原因：
# ipywidgets 没装或版本不兼容
# 你在 不支持 widgets 的环境里运行（比如纯脚本、某些老版本的 VSCode/JupyterLab）
# Jupyter 前端扩展没有启用/加载

# %%
# profile.to_notebook_iframe()   # 在 notebook 里嵌入
# # 或
# profile.to_file("report.html") # 生成 HTML 文件
